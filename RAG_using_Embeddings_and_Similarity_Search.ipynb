# %% [markdown]
# <a href="https://colab.research.google.com/github/aipractices/genai-application-collab-excercise/blob/main/RAG_using_Embeddings_and_Similarity_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Getting Started
#
# Here's how to get started:
# - Sign up for [Google Cloud](https://console.cloud.google.com/) (if you haven't already). Enable the Gemini API
# - Head over to [Google AI Studio](https://aistudio.google.com/apikey) and create API key for your project.

# %% [markdown]
# # Understanding Embeddings
#
# Embeddings are the vector representation of a sentence, and used to find relation with a query and data. Like in below example there are some titles for specific content. Using embdedings and similarity search we can find the closest match to the prompt.

# %%
# !pip install requests
# !pip install beautifulsoup4 pandas numpy

import os
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

model = 'models/embedding-001'

def pageEmbeddings(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             task_type="retrieval_document",
                             title=title)["embedding"]


def knowledgeBase():
  pages = [
    {
      "title": "Open-sources and Community Applications",
      "content": "https://thinkuldeep.com/about/open-sources/"
    },
    {
      "title": "Live Streaming, Webinars",
      "content": "https://thinkuldeep.com/about/streaming/"
    },
    {
      "title": "Patents Granted",
      "content": "https://thinkuldeep.com/about/patents/"
    },
    {
      "title": "Awards received and public coverage",
      "content": "https://thinkuldeep.com/about/recognitions/"
    },
    {
      "title": "Me, my family and some moments, travel and trips",
      "content": "https://thinkuldeep.com/about/moments/"
    },
    {
      "title": "Book foreword, reviewed and authored",
      "content": "https://thinkuldeep.com/about/books/"
    }
  ]

  df = pd.DataFrame(pages)
  df.columns = ['Title', 'Url']

  df['Embeddings'] = df.apply(lambda row: pageEmbeddings(row['Title'], row['Url']), axis=1)
  return df


def findBestPage(query, dataframe):
  query_embedding = genai.embed_content(model=model,
                                        content=query,
                                        task_type="retrieval_query")
  dot_products = np.dot(np.stack(dataframe['Embeddings']), query_embedding["embedding"])
  idx = np.argmax(dot_products)
  return dataframe.iloc[idx]['Url']


prompt = "Tell me in brief Kuldeep's streaming"

bestPage = findBestPage(prompt, knowledgeBase())

print(bestPage)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# https://thinkuldeep.com/about/streaming/

# %% [markdown]
# # Implementing RAG using Similaliry Search on Embeddings

# %% [markdown]
# Let's build a chatbot, that gives better result based on best match and additional context. Ask specific questions about Kuldeep.

# %%
# !pip install requests
# !pip install beautifulsoup4 pandas numpy
from google.colab import userdata

import os
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import google.generativeai as genai


genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

model = genai.GenerativeModel("models/gemini-2.0-flash")

chat = model.start_chat()

model = 'models/embedding-001'
def pageEmbeddings(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             task_type="retrieval_document",
                             title=title)["embedding"]
def knowledgeBase():
  pages = [
    {
      "title": "Open-sources and Community Applications",
      "content": "https://thinkuldeep.com/about/open-sources/"
    },
    {
      "title": "Live Streaming, Webinars",
      "content": "https://thinkuldeep.com/about/streaming/"
    },
    {
      "title": "Patents Granted",
      "content": "https://thinkuldeep.com/about/patents/"
    },
    {
      "title": "Awards received and public coverage",
      "content": "https://thinkuldeep.com/about/recognitions/"
    },
    {
      "title": "Me, my family and some moments, travel and trips",
      "content": "https://thinkuldeep.com/about/moments/"
    },
    {
      "title": "Book foreword, reviewed and authored",
      "content": "https://thinkuldeep.com/about/books/"
    }
  ]

  df = pd.DataFrame(pages)
  df.columns = ['Title', 'Url']

  df['Embeddings'] = df.apply(lambda row: pageEmbeddings(row['Title'], row['Url']), axis=1)
  return df


def findBestPage(query, dataframe):
  query_embedding = genai.embed_content(model=model,
                                        content=query,
                                        task_type="retrieval_query")
  dot_products = np.dot(np.stack(dataframe['Embeddings']), query_embedding["embedding"])
  idx = np.argmax(dot_products)
  return dataframe.iloc[idx]['Url']

def retrive(url):
  try:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    text_content = ""
    for paragraph in soup.find_all("p"):
        text_content += paragraph.get_text(strip=True) + "\n"
    for h2 in soup.find_all("h2"):
        text_content += h2.get_text(strip=True) + "\n"
    for h3 in soup.find_all("h3"):
        text_content += h3.get_text(strip=True) + "\n"
    for h4 in soup.find_all("h4"):
        text_content += h4.get_text(strip=True) + "\n"

    #print(text_content)
    return text_content
  except requests.exceptions.RequestException as e:
    return f"Error fetching URL: {e}"
  except Exception as e:
    return f"An error occurred: {e}"

def augment(prompt, context):
  return f"{prompt}. Here is more context: {context}"

def generation(prompt):
  return chat.send_message(prompt)

def run_chatbot():
    print("Hello! ask me about Kuldeep Singh! Type 'quit' to exit.")

    generation(augment("", retrive("https://thinkuldeep.com/about/")))

    df = knowledgeBase();

    while True:
        user_input = input("You: ")
        if user_input.lower() == 'quit':
            print("thinkuldeep: Goodbye!")
            break

        bestPageMatching = findBestPage(user_input, df)
        response = generation(augment(user_input, retrive(bestPageMatching)))
        print(f"thinkuldeep: {response.text} \n\n")

run_chatbot()
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Hello! ask me about Kuldeep Singh! Type 'quit' to exit.
# You: what his contribution to society
# thinkuldeep: Okay, incorporating the additional context, here's an updated view of Kuldeep's contributions to society, with a focus on showcasing their impact:
#
# **VIII. Societal Contributions & Community Engagement**
#
# Kuldeep is deeply committed to contributing to society through knowledge sharing, mentoring, and support for diverse communities. His impact extends beyond his professional work, influencing the lives of individuals and fostering innovation.
#
# *   **Knowledge Sharing & Education:**
#     *   **Events & Articles:** Shared knowledge and experience with 50,000+ people through 60+ events and 130+ articles on technology, leadership, and motivation.
#     *   **Publications:** Authored "Exploring the Metaverse" to promote responsible technology adoption.
#     *   **Guest Lectures:** Frequent guest lecturer at universities such as NIT Calicut and DesignersX, inspiring and educating the next generation of technologists.
#     *   **Judging & Mentoring:** Serves as a judge and mentor for initiatives like the Smart India Hackathon, guiding students and fostering innovation.
#
# *   **Mentorship & Community Support:**
#     *   **PeriFerry:** Provides life-changing mentoring experiences to the trans community, empowering individuals through guidance and support.
#     *   **Dream Mentor & tealfeed.com:** Mentors individuals and shares knowledge on social platforms to inspire and guide others.
#     *   **Advisor to Young Entrepreneurs:** Provides guidance and support to young entrepreneurs, helping them develop their businesses and contribute to the economy.
#     *   **Volunteer at Non-Profit Initiatives:** Actively volunteers his time and expertise to support various non-profit organizations.
#
# *   **Innovation for Societal Benefit:**
#     *   **Patents:** Holds patents (#11,988,832 B2 and #12,081,729 B2) for inventions that potentially contribute to advancements in technology and improve people's lives (Details in ☞ More Details).
#     *   **Technology Evangelism:** Promotes concepts like the connected worker, installation assistant, and digital twin to improve efficiency, safety, and quality of life in various industries.
#     *   **Responsible Metaverse Alliance and World Metaverse Council:** Actively participates in these organizations to guide the ethical and responsible development of metaverse technologies.
#
# *   **Recognition & Awards:**
#     *   **India Achievers’ Award 2022:** Recognized for significant contributions and achievements.
#     *   **NITK Alumni Recognition:** Acknowledged by his alma mater for his professional accomplishments and societal impact.
#
# **Enhancements & Considerations:**
#
# *   **Specific Examples:** If possible, include specific examples of the impact of the inventions covered by the patents. What problem do they solve, and who benefits? (Link to "More Details" for the patents)
# *   **Impact Metrics:** Whenever possible, quantify the impact of Kuldeep's contributions.  For example, "Mentored X number of individuals at PeriFerry," or "Helped Y number of startups through advising."
# *   **Testimonials:** Add quotes from individuals he has mentored or organizations he has supported, highlighting the positive impact of his involvement.
# *   **Call to Action:** Encourage readers to learn more about his initiatives or to get involved in supporting the causes he champions. For example, "Learn more about PeriFerry and how you can support the trans community."
#
# This expanded section will provide a much clearer and more impactful picture of Kuldeep's contributions to society.  It moves beyond simply listing activities and highlights the real-world impact of his work. Remember to populate the "More Details" links with relevant information.
#
#
#
# You: open source
# thinkuldeep: Okay, let's integrate the open-source contributions into Kuldeep's profile, highlighting his involvement and the value of each project. This will fit into section VII - "Societal Contributions & Community Engagement", subsection "Innovation for Societal Benefit"
#
# **VIII. Societal Contributions & Community Engagement**
#
# Kuldeep is deeply committed to contributing to society through knowledge sharing, mentoring, and support for diverse communities. His impact extends beyond his professional work, influencing the lives of individuals and fostering innovation.
#
# *   **Knowledge Sharing & Education:**
#     *   **Events & Articles:** Shared knowledge and experience with 50,000+ people through 60+ events and 130+ articles on technology, leadership, and motivation.
#     *   **Publications:** Authored "Exploring the Metaverse" to promote responsible technology adoption.
#     *   **Guest Lectures:** Frequent guest lecturer at universities such as NIT Calicut and DesignersX, inspiring and educating the next generation of technologists.
#     *   **Judging & Mentoring:** Serves as a judge and mentor for initiatives like the Smart India Hackathon, guiding students and fostering innovation.
#
# *   **Mentorship & Community Support:**
#     *   **PeriFerry:** Provides life-changing mentoring experiences to the trans community, empowering individuals through guidance and support.
#     *   **Dream Mentor & tealfeed.com:** Mentors individuals and shares knowledge on social platforms to inspire and guide others.
#     *   **Advisor to Young Entrepreneurs:** Provides guidance and support to young entrepreneurs, helping them develop their businesses and contribute to the economy.
#     *   **Volunteer at Non-Profit Initiatives:** Actively volunteers his time and expertise to support various non-profit organizations.
#
# *   **Innovation for Societal Benefit:**
#     *   **Patents:** Holds patents (#11,988,832 B2 and #12,081,729 B2) for inventions that potentially contribute to advancements in technology and improve people's lives (Details in ☞ More Details).
#     *   **Technology Evangelism:** Promotes concepts like the connected worker, installation assistant, and digital twin to improve efficiency, safety, and quality of life in various industries.
#     *   **Responsible Metaverse Alliance and World Metaverse Council:** Actively participates in these organizations to guide the ethical and responsible development of metaverse technologies.
#     *   **Open-Source Contributions:**  Actively contributes to open-source projects, promoting collaboration, knowledge sharing, and innovation within the developer community.  Key contributions include:
#
#         *   **OpenThread Commissioner Implementation in Java:** Developed a step-by-step guide for developers to build an external Commissioner in Java, bridging the gap in OpenThread's open-source project. This enables more accessible and versatile commissioning for IoT devices. (☞ Github☞ Learn More)
#
#         *   **MQTT-Remote:** Created a web-based remote control for LEDs, providing a simple and intuitive interface to control hardware devices. (☞ Live Demo☞ Github☞ Learn More)
#
#         *   **ModelViewer:** Demonstrated WebXR and 3D Printing capabilities, offering a platform for exploring and experimenting with these emerging technologies. (☞ Live Demo☞ Github☞ Learn WebXR)
#
#         *   **3D Book:** Implemented a virtual book with realistic page-turning effects, showcasing interactive and engaging digital reading experiences. (☞ Github☞ Book launch - Five thoughtful years)
#
#         *   **Arium — An Automation framework for Unity/XR:** Contributes as a core developer and reviewer for Arium, a lightweight and extensible framework for writing automation tests in Unity specifically for XR (AR/VR) applications, promoting quality assurance in XR development. (☞ GitHub☞ Medium Article☞ Thoughtworks Insights)
#
#         *   **DecoAR — Decorate the world with XR:** Developed DecoAR, an app that allows users to augment their surroundings with virtual decorations using smart glasses, demonstrating the potential of AR for personalized and interactive experiences. (☞ More details☞ Github☞ Medium)
#
#         *   **Pair Generator - Conducting feedback made easy:** Created a tool to automate the pairing of individuals for 1-1 feedback sessions, streamlining the feedback process and saving time for teams. (☞ Try is Live☞ Github)
#
#         *   **Why Worry - Life is simple, we make it complex:** Developed an app designed to reduce anxiety by promoting mindfulness and problem-solving strategies. (☞ Try is Live☞ Github☞ Read more about balancing life)
#
#         *   **Image-evaluator - online assessment tool:** Built an online tool for evaluating images using simple JavaScript, enabling quick and accessible image analysis. (☞ Try is Live☞ Github)
#
# *   **Recognition & Awards:**
#     *   **India Achievers’ Award 2022:** Recognized for significant contributions and achievements.
#     *   **NITK Alumni Recognition:** Acknowledged by his alma mater for his professional accomplishments and societal impact.
#
# **Enhancements & Considerations:**
#
# *   **Quantify Usage:**  If possible, quantify the usage of his open-source projects. For example, "X number of downloads" or "Used by Y organizations."
# *   **Highlight Specific Contributions:** For each project, briefly describe the specific code contributions he made, such as "Implemented key features for XYZ module."
# *   **License Information:** Consider adding the license information for each open-source project (e.g., MIT License, Apache 2.0).
# *   **Keep Links Updated:** Ensure all links to GitHub repositories, live demos, and articles are up-to-date.
#
# By integrating his open-source contributions in this way, you showcase his technical skills, his commitment to collaboration, and the real-world impact of his work on the developer community and beyond. This creates a more compelling and well-rounded picture of his overall contributions.
#
#
#
# You: when was hi live
# thinkuldeep: Okay, let's create a section dedicated to Kuldeep's speaking engagements and live appearances, organizing them chronologically (where possible) for a clear view of his activity and expertise. This will further enhance section VIII "Societal Contributions & Community Engagement", adding a subsection "Speaking Engagements & Live Appearances"
#
# **VIII. Societal Contributions & Community Engagement**
#
# Kuldeep is deeply committed to contributing to society through knowledge sharing, mentoring, and support for diverse communities. His impact extends beyond his professional work, influencing the lives of individuals and fostering innovation.
#
# *   **Knowledge Sharing & Education:**
#     *   **Events & Articles:** Shared knowledge and experience with 50,000+ people through 60+ events and 130+ articles on technology, leadership, and motivation.
#     *   **Publications:** Authored "Exploring the Metaverse" to promote responsible technology adoption.
#     *   **Guest Lectures:** Frequent guest lecturer at universities such as NIT Calicut and DesignersX, inspiring and educating the next generation of technologists.
#     *   **Judging & Mentoring:** Serves as a judge and mentor for initiatives like the Smart India Hackathon, guiding students and fostering innovation.
#
# *   **Mentorship & Community Support:**
#     *   **PeriFerry:** Provides life-changing mentoring experiences to the trans community, empowering individuals through guidance and support.
#     *   **Dream Mentor & tealfeed.com:** Mentors individuals and shares knowledge on social platforms to inspire and guide others.
#     *   **Advisor to Young Entrepreneurs:** Provides guidance and support to young entrepreneurs, helping them develop their businesses and contribute to the economy.
#     *   **Volunteer at Non-Profit Initiatives:** Actively volunteers his time and expertise to support various non-profit organizations.
#
# *   **Innovation for Societal Benefit:**
#     *   **Patents:** Holds patents (#11,988,832 B2 and #12,081,729 B2) for inventions that potentially contribute to advancements in technology and improve people's lives (Details in ☞ More Details).
#     *   **Technology Evangelism:** Promotes concepts like the connected worker, installation assistant, and digital twin to improve efficiency, safety, and quality of life in various industries.
#     *   **Responsible Metaverse Alliance and World Metaverse Council:** Actively participates in these organizations to guide the ethical and responsible development of metaverse technologies.
#     *   **Open-Source Contributions:**  Actively contributes to open-source projects, promoting collaboration, knowledge sharing, and innovation within the developer community.  Key contributions include:
#         *   **(List of Open-Source Contributions from previous answer)**
#
# *   **Speaking Engagements & Live Appearances:**  Kuldeep is a sought-after speaker and thought leader, actively participating in webinars, conferences, and podcasts to share his expertise on emerging technologies.
#
#     *   **Upcoming:**
#         *   Gatherverse Summit 2025 (☞ More Details)
#
#     *   **2024:**
#         *   Gatherverse XREvolve Summit 2024 (☞ More Details)
#         *   Gatherverse Virtual World Symposium 2024 (☞ More Details)
#         *   AWE Asia 2024 (☞ More Details)
#         *   Season of AI - Azure Developer Community - Rekill (☞ More Details)
#         *   Express Computer Webinar (☞ More Details)
#
#     *   **2022:**
#         *   Thoughtworks XConf 2022 (☞ More Details)
#
#     *   **2021:**
#         *   Thoughtworks MasterClass-2021 (☞ More Details)
#         *   Thoughtworks XConf 2021 (☞ More Details)
#
#     *   **Other (Dates Unknown or Not Specified):**
#         *   The Metaverse United : How AI and XR Can Deepen Human Connections
#         *   Defining the AI Powered Virtual World
#         *   India’s Metaverse Journey: Opportunities and Challenges
#         *   Global Insights from XR Leaders in India: AI-Powered Real-Time Adaptation in XR
#         *   Harnessing Business Opportunity with AI Powered XR
#         *   Azure AI Fostering Sense within XR World
#         *   Evolving into Tomorrow, Today: Enter the Metaverse
#         *   Exploring the Metaverse: Redefining the reality in the digital age
#         *   XR in practice: the engineering challenges of extending reality
#         *   AI Assisted Content Pipeline for XR
#         *   Using XR in building autonomous vehicles
#         *   The Shift from Enterprise XR to Ethical XR
#         *   Navigating the new normal
#         *   eXtended Reality for Enterprise
#         *   XR - Nicety to Necessity
#         *   How to get started with AR VR?
#         *   SLAM Aware Applications
#         *   XROM Postcast (☞ More Details)
#         *   XROM Podcast (☞ More Details)
#         *   Techgig Webinars (☞ More Details)
#         *   Google Developer Student Club (☞ More Details)
#         *   Book promo (☞ More Details)
#         *   Thoughtworks Podcast (☞ More Details)
#         *   The VRARA (☞ More Details)
#
#     *   **2019:**
#         *   ThoughtWorks Away Day 2019 (☞ More Details)
#
# *   **Recognition & Awards:**
#     *   **India Achievers’ Award 2022:** Recognized for significant contributions and achievements.
#     *   **NITK Alumni Recognition:** Acknowledged by his alma mater for his professional accomplishments and societal impact.
#
# **Enhancements & Considerations:**
#
# *   **Link Recordings:** Whenever possible, provide links to recordings of the talks, webinars, or podcast appearances.  This allows viewers to directly access the content.
# *   **Brief Descriptions:**  Add a 1-2 sentence description of the topic covered in each engagement. This gives context and highlights the range of his expertise.
# *   **Audience Size/Reach:** If available, provide information on the audience size or reach of each event (e.g., "Webinar with 500+ attendees").
# *   **Key Takeaways:** Consider summarizing the key takeaways from some of the more prominent engagements.
#
# This detailed "Speaking Engagements & Live Appearances" section demonstrates his active involvement in the technology community and his commitment to sharing his knowledge and insights. It further solidifies his position as a thought leader and expert in his field.
#
#
#
# You: when was his last streaming
# thinkuldeep: Based on the provided list, determining the absolute *last* streaming event is difficult without specific dates for each. However, we can identify the *most recent events* that are *likely* to be streaming appearances, based on the event names and the order presented (assuming the list is ordered reverse chronologically).
#
# **The most recent likely streaming/live events are:**
#
# *   **Gatherverse Summit 2025:** This is a future event, so it *will be* a streaming or in-person appearance, assuming Kuldeep participates.
#
# *   **Events in 2024:** Since 2024 is more recent than 2022, 2021, and 2019, the following events are more likely to be the last streaming appearances:
#     *   Gatherverse Virtual World Symposium 2024
#     *   AWE Asia 2024
#     *   Express Computer Webinar
#     *   Season of AI - Azure Developer Community - Rekill
#     *   Gatherverse XREvolve Summit 2024
#
# **To definitively determine the last streaming event:**
#
# 1.  **Look for specific dates:** The "More Details" links would ideally lead to pages with specific dates for each event.
# 2.  **Consider Webinar/Podcast Formats:** Webinars and podcasts are *inherently* streamed or recorded live.
#
# **Here's how to update the "Speaking Engagements & Live Appearances" section to reflect this uncertainty:**
#
# *   **Speaking Engagements & Live Appearances:** Kuldeep is a sought-after speaker and thought leader, actively participating in webinars, conferences, and podcasts to share his expertise on emerging technologies.
#
#     *   **Upcoming:**
#         *   Gatherverse Summit 2025 (☞ More Details)
#
#     *   **Most Recent Engagements (Likely Streaming Appearances):** *[It's important to note that without exact dates, the order below assumes the list provided is reverse chronological. Please confirm event dates via the "More Details" links for accurate ordering.]*
#
#         *   Gatherverse XREvolve Summit 2024 (☞ More Details)
#         *   Gatherverse Virtual World Symposium 2024 (☞ More Details)
#         *   AWE Asia 2024 (☞ More Details)
#         *   Season of AI - Azure Developer Community - Rekill (☞ More Details)
#         *   Express Computer Webinar (☞ More Details)
#         *[Based on available information, these events from 2024 are likely the most recent streaming engagements, however please check the links for date confirmation.]*
#
#     *   **Past Engagements:**
#
#         *   **(List of past engagements from 2022, 2021, 2019, and Undated events).**
#
# **Key Changes:**
#
# *   **Added a Disclaimer:** The note about the order being based on assumption. This is critical for transparency.
# *   **Focused on "Likely Streaming Appearances":** This acknowledges that not every item in the list may have been a live stream.
# *   **Emphasized "Confirm Dates":** This encourages someone maintaining the profile to verify the information.
#
# By making these changes, the profile is both accurate and provides the best information available from the provided context. As more information becomes available (e.g., exact dates for each event), the section can be updated for even greater precision.
